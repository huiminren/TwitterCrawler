# %% [markdown]
# # How to crawl data from Twitter without using Twitter API
# * Connect to the link
# * Parser html
# * Store data

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
company_list = ['microsoft','apple']
startID_list = ['869627961883803648','864110182892261379']

# %% [markdown]
# ** Connect to the link **
# 1. Use Developer Tools (right click of 'Inspect' in Chrome).
# 2. Click 'Network' to find the real link which includes the information you need. Usually it is different from the website in your browser. In this case, the real link starts with 'timeline?'.
# 3. Click 'Headers' to find 'Request Headers' and 'Query String Paramters', which will be needed when you set header and param.
# 4. Copy all the information in 'Request Headers' to header={}, except 'cookie'. Note that 'user-agent' is the most import element in this method.
# 5. Copy all the information in 'Query String Paramters' to param{}.
# 6. Set response.

# %%
# First test with neurodiversity microsoft since:2015-04-30 until:2017-04-30
# https://twitter.com/search?l=en&q=neurodiversity%20microsoft%20%20since%3A2015-01-01%20until%3A2017-05-31&src=typd&lang=en
def connectTwitter(company,endID,startID):
    url = 'http://twitter.com/search'
    param = {
        'vertical':'default',
        'q':'since:2015-01-01 until:2017-05-31 neurodiversity '+company,# since:2015-01-01 until:2017-05-31
        'l':'en',
        'src':'typd',
        'include_available_features':'1',
        'include_entities':'1',
        'lang':'en',
        'max_position':'TWEET-'+endID+'-'+startID+'-BD1UO2FFu9QAAAAAAAAETAAAAAcAAAASAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA',
        'reset_error_state':'false'
    } # TWEET-857-857 means starting with the first page.
    header = {
        'accept':'application/json, text/javascript, */*; q=0.01',
        'accept-encoding':'gzip, deflate, sdch, br',
        'accept-language':'en,zh-CN;q=0.8,zh;q=0.6,en-US;q=0.4',
        'dnt':'1',
        'referer':'https://twitter.com/search?l=&q=&src=typd&vertical=&max_position=&',# Remove the information that
                                                                                       # param has included.
        'user-agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36',
        'x-requested-with':'XMLHttpRequest',
        'x-twitter-active-user':'yes'
    }
    response = requests.get(url,params=param, headers=header)
    html = response.content.decode('utf-8')
    soup = BeautifulSoup(html,'lxml')
    
    try:
        tweets_html_id = soup.find_all('div',class_='stream')[0].find_all('li')
        tweets_id = [tweet_html_id.get('data-item-id') for tweet_html_id in tweets_html_id]
        tweets_id = [t for t in tweets_id if t is not None]
        next_endID = tweets_id[len(tweets_id)-1]
        
    except IndexError:
        soup = None
        next_endID = None

    return soup,next_endID

# %% [markdown]
# ** Parser HTML and Store data to DataFrame**

# %%
# DOM Parser
def parser_DF(soup):
    tweets_html = soup.find_all('li',class_='js-stream-item stream-item stream-item ') # note of the space
    # get user name
    tweets_username = [tweet_html.find('div').get('data-screen-name') 
                           for tweet_html in tweets_html]
    # get DataTime
    tweets_datetime = [tweet_html.find('small',class_='time').find('a').get('title') 
                           for tweet_html in tweets_html]
    # get content
    tweets_content = [tweet_html.find('p',class_='TweetTextSize js-tweet-text tweet-text').text.strip() 
                          for tweet_html in tweets_html]
    # get replies, retweets, likes
    tweets_replies = [tweet_html.find('span',class_='ProfileTweet-action--reply u-hiddenVisually').find('span')
                          .get('data-tweet-stat-count') for tweet_html in tweets_html]
    tweets_retweet = [tweet_html.find('span',class_='ProfileTweet-action--retweet u-hiddenVisually').find('span')
                          .get('data-tweet-stat-count') for tweet_html in tweets_html]
    tweets_likes = [tweet_html.find('span',class_='ProfileTweet-action--favorite u-hiddenVisually').find('span')
                          .get('data-tweet-stat-count') for tweet_html in tweets_html]
    # get image link
    tweets_image=[]
    tweets_image_html = [tweet_html.find('div',class_='AdaptiveMedia-singlePhoto') for tweet_html in tweets_html]
    for tweet_image_html in tweets_image_html:
        if tweet_image_html is not None:
            tweets_image.append(tweet_image_html.find('div').get('data-image-url'))
        else:
            tweets_image.append(None)
    # get verified account
    tweets_verified=[]
    tweets_html[6].find('span',class_='Icon Icon--verified')
    tweets_verified_html = [tweet_html.find('span',class_='Icon Icon--verified') for tweet_html in tweets_html]
    for tweet_verified_html in tweets_verified_html:
        if tweet_verified_html is None:
            tweets_verified.append(0)
        else:
            tweets_verified.append(1)
    
    # store data to dataframe        
    tweets = [('username',tweets_username),
              ('verified',tweets_verified),
              ('DateTime',tweets_datetime),
              ('content',tweets_content),
              ('likes',tweets_likes),
              ('retweet',tweets_retweet),
              ('replies',tweets_replies),
              ('image',tweets_image)]

    tweets_df = pd.DataFrame.from_items(tweets)
    
    return tweets_df

# %% [markdown]
# Call Method

# %%
# Automatically get lastID and go to next page
companies_html = [] # global variable
for i in range(len(company_list)): # for loop of company_list
    soup_list=[]
    id_list=[]

    if len(id_list)==0: # First page: startID and endID would be the same
        s = connectTwitter(company_list[i],startID_list[i],startID_list[i])
        soup_list.append(s[0])
        id_list.append(s[1])

    if len(id_list)>=1:
        while(id_list[-1] is not None):
            s = connectTwitter(company_list[i],id_list[-1],startID_list[i])
            soup_list.append(s[0])
            id_list.append(s[1])

    if(id_list[-1] is None): # because of the try catch in the def
        del soup_list[-1]
        del id_list[-1]
        
    companies_html.append(soup_list)

# %%
# parse html and merge dataframe
companies_df_list = [] # global variable
for j in range(len(companies_html)):
    tweets_df_list = []
    for soup in companies_html[j]:
        tweets_df = parser_DF(soup)
        tweets_df_list.append(tweets_df)
    companies_df_list.append(pd.concat(tweets_df_list,ignore_index=True))
    companies_df_list[j].to_csv(company_list[j]+'.csv')

# %%
companies_df_list[0]
# Out:
#             username  verified                DateTime  \
# 0      nicolelweston         0  11:45 AM - 30 May 2017
# 1         zipmydress         0   3:32 PM - 23 May 2017
# 2          MikeCamel         0    8:33 AM - 4 May 2017
# 3         MSFTEnable         1   1:19 AM - 26 Apr 2017
# 4     100PercentWine         0   2:59 PM - 24 Apr 2017
# 5       derickfisher         0   2:09 PM - 22 Apr 2017
# 6            morl8tr         0  11:18 AM - 13 Apr 2017
# 7          JenBeason         0  10:32 AM - 13 Apr 2017
# 8           leecm363         0   9:39 AM - 12 Apr 2017
# 9             PRFund         0    8:50 AM - 1 Apr 2017
# 10       FRCteam4911         1  12:19 PM - 21 Mar 2017
# 11         RyanDCook         0  11:00 AM - 24 Feb 2017
# 12     onBoardCanada         0   8:55 AM - 11 Feb 2017
# 13       MicrosoftSV         1   11:10 AM - 5 Jan 2017
# 14    Jill_T_Elliott         0   8:31 AM - 28 Dec 2016
# 15         draorose1         0  11:43 AM - 26 Dec 2016
# 16       dyslexicadv         1   4:01 PM - 19 Dec 2016
# 17    washingtonstem         0    6:50 PM - 8 Dec 2016
# 18           LEADCtr         0  10:15 AM - 21 Nov 2016
# 19     propellerites         0    2:25 AM - 2 Nov 2016
# 20     WarrenMasonNY         0   9:51 AM - 24 Oct 2016
# 21         DBaker007         0   7:25 PM - 22 Oct 2016
# 22   sunjeet_khokhar         0   2:10 PM - 19 Oct 2016
# 23    shirleytricker         0   2:09 PM - 19 Oct 2016
# 24       JoeClibbens         0   1:42 PM - 19 Oct 2016
# 25         draorose1         0   7:08 PM - 17 Oct 2016
# 26          debraruh         0   3:40 PM - 16 Oct 2016
# 27     Laradenisepls         0   1:41 PM - 14 Oct 2016
# 28    RightBrain_Net         0   8:01 AM - 10 Oct 2016
# 29       andreachiou         0    2:33 AM - 6 Oct 2016
# ..               ...       ...                     ...
# 157        JJRTaylor         0    9:10 AM - 2 Jun 2015
# 158          jackhar         0    8:00 AM - 2 Jun 2015
# 159       MSFTEnable         1    6:35 AM - 2 Jun 2015
# 160        JohnJReid         0    2:09 PM - 1 Jun 2015
# 161            pensf         0   12:18 PM - 1 Jun 2015
# 162   stevesilberman         1   11:22 AM - 1 Jun 2015
# 163         Netwoven         0   11:15 AM - 1 Jun 2015
# 164  elishevaschwart         0    8:07 AM - 1 Jun 2015
# 165   MonsterPhonics         0  12:02 AM - 30 May 2015
# 166        IDAnorcal         0   4:25 AM - 29 May 2015
# 167          jackhar         0   2:10 PM - 28 May 2015
# 168    TMAndrews2006         0   6:19 AM - 28 May 2015
# 169  headstrongnatio         0  12:16 PM - 27 May 2015
# 170  neuro_diversity         0   4:39 AM - 27 May 2015
# 171    SquarePegLabs         0   1:42 PM - 26 May 2015
# 172       Aspertools         0  12:56 PM - 26 May 2015
# 173        harsh0402         0   5:12 AM - 26 May 2015
# 174   stevesilberman         1  11:58 AM - 23 May 2015
# 175        StuShader         0  11:52 AM - 23 May 2015
# 176  neuro_diversity         0   7:45 AM - 23 May 2015
# 177       TheCodpast         0   3:01 AM - 23 May 2015
# 178         Netwoven         0   8:53 AM - 21 May 2015
# 179        IDAnorcal         0    1:02 PM - 9 May 2015
# 180       Aspertools         0   2:52 PM - 30 Apr 2015
# 181    Diversability         0   2:32 PM - 22 Apr 2015
# 182     KellyPriest3         0    7:37 PM - 8 Apr 2015
# 183      quinndupont         0    9:03 AM - 8 Apr 2015
# 184      annekeseley         0    4:20 PM - 7 Apr 2015
# 185   NorthernSpeech         0    1:06 PM - 6 Apr 2015
# 186            dcsaw         0   10:10 AM - 6 Apr 2015
#
#                                                content likes retweet replies  \
# 0    More companies are reforming their HR processe...     0       0       0
# 1    ZMD is @Microsoft #Inclusion Conference! Ferna...     0       0       0
# 2    Attending a session on "Neurodiversity in the ...     1       0       0
# 3    "Neurodiversity in the workforce" with Stu Sha...     5       4       0
# 4    @Microsoft's neurodiversity program for people...     4       4       0
# 5    @microsoft and other have been adapting to #ne...     0       0       0
# 6    SAP, HPE, Microsoft, and EY sharing know-how a...     7       0       0
# 7    So cool that @HPE @sap @microsoft + more comin...     4       0       1
# 8    The Neurodiversity Movement Finds a Friend in ...     3       4       0
# 9    #Dyslexia and Neurodiversity in the High Tech ...     2       0       0
# 10   @Microsoft we are looking forward to a continu...     3       1       0
# 11   See how "neurodiversity" benefits workplaces s...     1       2       0
# 12   Microsoft's Autism pilot project is proving su...     8       3       0
# 13   #Inclusive hiring is important — why some comp...     7       2       0
# 14   Companies #Hiring Workers w/ #Autism-The Atlan...     2       1       0
# 15   See how companies like Microsoft are trying to...     1       0       0
# 16   #Dyslexia & Neurodiversity in High Tech Workfo...     9       7       0
# 17   .@Microsoft  and some other companies are wide...     6       2       0
# 18   Read about Blake – a Systems Engineer w/ #Aspe...     0       0       0
# 19   .@Microsoft championing neurodiversity, using ...     1       0       0
# 20   Diverse #talent results in unique perspectives...     2       1       0
# 21   #Microsoft Wants #Autistic #Coders. Can It Fin...     0       0       0
# 22   @Maltekk  powerful slide on neurodiversity ......     3       2       0
# 23   @Maltekk speaking at @WeTestNZ about @Microsof...     0       0       0
# 24   Microsoft works on improving its neurodiversit...     0       0       0
# 25   #neurodiversity at a conference hosted at Micr...     1       0       0
# 26   The Neurodiversity Movement Finds a Friend in ...     1       1       0
# 27   Once again I love this! #neurodiversity #ASD #...     1       0       0
# 28   Improving "neurodiversity" : Microsoft’s jobs ...     0       0       0
# 29   As I typed notes on @SalFreudenberg talk on ne...     1       0       0
# ..                                                 ...   ...     ...     ...
# 157  Thank you @StuShader for putting on such a gre...     3       8       1
# 158  Meet up with @Netwoven today @Microsoft #Neuro...     0       0       0
# 159  Today: Microsoft, featured speakers and paneli...     1       2       0
# 160  Looking forward to Microsoft's event "Neurodiv...     0       0       0
# 161  Tomorrow! Neurodiversity in the High-Tech Work...     0       1       0
# 162  Tomorrow, Microsoft will host its first #neuro...     9       6       3
# 163  Don't miss @Microsoft @Netwoven sponsored #Neu...     0       0       0
# 164  @ScottDSandell Looking forward to seeing you t...     0       0       0
# 165  Netwoven to Sponsor Microsoft's #Neurodiversit...     0       0       0
# 166  Join us at Microsoft for a FREE event this Tue...     0       0       0
# 167  Via @imagesourcemag @Netwoven To Sponsor @Micr...     0       0       0
# 168  @Netwoven @Microsoft Please support those w #F...     0       1       0
# 169  Neurodiversity in the High-Tech Workforce Even...     0       2       0
# 170  @Microsoft @Netwoven sponsor US #neurodiversit...     0       1       1
# 171  .@Microsoft @Netwoven sponsor #neurodiversity ...     2       1       1
# 172  @Netwoven sponsors the @Microsoft #neurodivers...     0       0       0
# 173  Netwoven to Sponsor Microsoft's Neurodiversity...     0       0       0
# 174  Great to see that Microsoft is hosting a confe...     5       2       1
# 175  @stevesilberman Wanted to get the word out abo...     1       0       1
# 176  Microsoft Conference in Silicon Valley, USA\n'...     0       0       0
# 177  Microsoft is hosting a free #Neurodiversity Co...     5       2       0
# 178  .@MicrosoftSV How Familiar Are You with #Neuro...     2       0       0
# 179  Join us at Microsoft for a FREE event-- Neurod...     0       1       0
# 180  Microsoft holding #neurodiversity conference i...     0       0       0
# 181  Looks like a great event from Microsoft -- Neu...     0       0       0
# 182  Big hug 4 #Microsoft #inclusion! Who'd U like ...     0       1       2
# 183  #neurodiversity Microsoft seeks to recruit aut...     0       0       0
# 184  If your goal is building a diverse organizatio...     0       0       0
# 185  Microsoft's new employment program may offer a...     0       0       0
# 186  #neurodiversity > RT @HuffingtonPost: Microsof...     0       0       0
#
#                                                image
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                               None
# 6    https://pbs.twimg.com/media/C9T_NuVUwAIy7PC.jpg
# 7    https://pbs.twimg.com/media/C9T0rLaUMAE1PyA.jpg
# 8                                               None
# 9                                               None
# 10                                              None
# 11                                              None
# 12                                              None
# 13                                              None
# 14                                              None
# 15                                              None
# 16   https://pbs.twimg.com/media/C0E-3GzXUAASJ9y.jpg
# 17                                              None
# 18                                              None
# 19   https://pbs.twimg.com/media/CwPzkxRWcAAUsZZ.jpg
# 20                                              None
# 21                                              None
# 22                                              None
# 23   https://pbs.twimg.com/media/CvKOkyFUIAAsjzW.jpg
# 24                                              None
# 25                                              None
# 26                                              None
# 27                                              None
# 28                                              None
# 29                                              None
# ..                                               ...
# 157  https://pbs.twimg.com/media/CGgfJnQUQAAMhIf.jpg
# 158                                             None
# 159                                             None
# 160                                             None
# 161                                             None
# 162                                             None
# 163                                             None
# 164                                             None
# 165                                             None
# 166                                             None
# 167                                             None
# 168                                             None
# 169                                             None
# 170                                             None
# 171                                             None
# 172                                             None
# 173                                             None
# 174                                             None
# 175                                             None
# 176                                             None
# 177                                             None
# 178                                             None
# 179                                             None
# 180                                             None
# 181                                             None
# 182                                             None
# 183                                             None
# 184                                             None
# 185                                             None
# 186                                             None
#
# [187 rows x 8 columns]

# %%
companies_df_list[1]
# Out:
#            username  verified               DateTime  \
# 0        JosCuadros         0   7:10 PM - 7 Mar 2017
# 1     LeesaVlahosMP         1  9:10 AM - 25 Oct 2016
# 2   dontdismyabilit         0   9:28 AM - 3 Sep 2016
# 3          Rom_Duck         0  8:38 AM - 11 May 2016
# 4         kit_boyer         0   9:32 PM - 4 Apr 2016
# 5         jrtgirl35         0   1:37 PM - 2 Apr 2016
# 6   KatKnoernschild         0  10:50 AM - 2 Apr 2016
# 7       excludenone         1  5:34 PM - 16 Jan 2016
# 8     AutismAdvoCat         0  8:46 AM - 18 Oct 2015
# 9      TraysJourney         0   7:56 PM - 6 Sep 2015
# 10       Aspertools         0  5:37 AM - 16 Aug 2015
#
#                                               content likes retweet replies  \
# 0   #Apple #Uber #Amazon #BrillantMind #Mind #Neur...     1       0       0
# 1   @Apple support vision hearing physical motor n...     0       1       0
# 2   Doesn't matter how great you are if no one can...     3       7       0
# 3   #FollowMe Rom_duck  #entrepreneurship #happyTi...     1       0       0
# 4   Apple's new film shows how tech transforms liv...     0       0       0
# 5   @tim_cook thankyou for promoting #AutismAccept...     0       0       0
# 6   #AutismAwareness ad by #Apple 'Dylan's Voice'....     0       0       0
# 7   @HuffingtonPost how does Apple measure up in #...     0       0       0
# 8   Interesting \nApple working with Autism\nresea...     1       1       0
# 9   Hi @brittopopart your apple sculpture was in a...     0       0       0
# 10  @Apple, @Intel Improve in Workplace Diversity ...     0       0       0
#
#                                               image
# 0                                              None
# 1                                              None
# 2   https://pbs.twimg.com/media/CrcVFSRWcAApAbE.jpg
# 3                                              None
# 4   https://pbs.twimg.com/media/CfQJKdaWQAI0m61.jpg
# 5                                              None
# 6                                              None
# 7                                              None
# 8                                              None
# 9                                              None
# 10                                             None
